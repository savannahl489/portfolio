# %% [markdown]
# # Framework for Analysis
#
# Before any guiding questions are crafted for the analysis, the real purpose of this project -- this whole repository -- needs to be revisited: the intention to showcase how I think and analyze data. Thus, questions that are asked and answers may have already been done so by others, but this is ultimately how I would begin to work through a new dataset on the job.
#
# This notebook will be used to structure the analysis and establish objectives for the analysis phase of the project. It will aim to result in 3-4 guiding questions that can be answered with a bevy of different methods. Thus, the language in this notebook will be more casual / brainstorming in nature as in the professional setting, this notebook would remain a private document.
#
# To begin, the data obtained is as follows:

# %%
import pandas as pd

df = pd.read_csv('./data/modified_sleep_health_and_lifestyle_dataset.csv')

df.columns
# Out:
# Index(['person_id', 'gender', 'age', 'occupation', 'sleep_duration',
#        'sleep_quality', 'physical_activity_level', 'stress_level',
#        'bmi_category', 'heart_rate', 'daily_steps', 'sleep_disorder',
#        'systolic', 'diastolic'],
#       dtype='object')

# %% [markdown]
# As noted in the EDA, the variables 'sleep_disorder', 'sleep_duration' and 'sleep_quality' are of immediate interest. Tangential to those would be health factors such as 'systolic', 'diastolic', 'heart_rate', and 'physical_activity_level'.
#
# Thus, the priortization of variables in this manner results in two tiers of questions: primary and secondary research questions.
#
# Under the primary questions:
# - What are great predictors of good sleep duration and sleep quality?
# - Are there patterns amongst individuals who have sleep disorders vs individuals who do not?
# - Is the type of sleep disorder reflected in the other variables/ can we differentiate between sleep disorders using the data provided?
#
# Secondary questions:
# - How correlated are variables like physical activity and heart rate or bmi category?
# - How do different health metrics differ with different occupations?
# - How does perceived stress level factor into health metrics?
#
# For now, I believe this is enough to explore. As analysis proceeds, additional questions may be explored.
